# %%
import pandas as pd
pd.options.display.float_format = '{:.5f}'.format

# %%
tkffuwnj = pd.read_csv('./csv/data/dataset/12345.csv')

# %%
tkffuwnj
# Out:
#          종목명  years  month  상장주식수대비월거래량합계_x         거래대금_x           상장시가총액  \
# 0        디씨엠   2019     10          0.13720  4421096.38095 1382344362.47619
# 1        디씨엠   2019      7          0.95086  4429029.47826 1386277749.39130
# 2        디씨엠   2019      8          0.85987  4662803.33333 1297011945.47619
# 3        디씨엠   2019      9          1.01791  4520648.36842 1366227666.63158
# 4        디씨엠   2019      2          1.00858  5618904.58824 1458848750.70588
# ...      ...    ...    ...              ...            ...              ...
# 31035    케이카   2021     10         38.59300 11753813.78947 2173605748.15789
# 31036    케이카   2021     11         56.81219 11717785.81818 2182238704.63636
# 31037  플레이그램   2021     12         59.34477  9919548.95455 2210272304.31818
# 31038  플레이그램   2021     11        137.09261 11717785.81818 2182238704.63636
# 31039   세기상사   2021     12        105.60136  9919548.95455 2210272304.31818
#
#        벤치마크지수     소외주        EPS      PER  ...       거래대금_y           시가총액  \
# 0     0.31972     소외주  715.00000 17.06000  ...     11216500   142740000000
# 1     0.31964  소외주가아님  715.00000 16.29000  ...     68155400   136305000000
# 2     0.35980  소외주가아님  715.00000 16.36000  ...     12583700   136890000000
# 3     0.33055  소외주가아님  715.00000 17.27000  ...      4068000   144495000000
# 4     0.38536  소외주가아님 1371.00000  7.91000  ...    213415100   126945000000
# ...       ...     ...        ...      ...  ...          ...            ...
# 31035 0.54153  소외주가아님  602.00000 40.70000  ...   3737886450  1178120058500
# 31036 0.53777  소외주가아님  602.00000 52.91000  ...  39709838000  1531556076050
# 31037 0.44895  소외주가아님   86.00000 29.88000  ...   6987045120   230572859620
# 31038 0.53777  소외주가아님   86.00000 30.70000  ...   7806513810   236853054240
# 31039 0.44895  소외주가아님        NaN      NaN  ...   1643249960    43204752000
#
#       상장주식수대비거래량    표준편차     거래량_합계  거래량_일평균       거래대금_합계     거래대금_일평균  \
# 0        0.00787 0.60545      16052      764     196689150      9366150
# 1        0.05030 1.01354     111251     4837    1317801050     57295698
# 2        0.00919 1.32400     100605     4791    1167465950     55593617
# 3        0.00283 1.09602     119095     6268    1452798150     76463061
# 4        0.16874 0.57177     118004     6941    1282297050     75429238
# ...          ...     ...        ...      ...           ...          ...
# 31035    0.31381 3.02241   18558037  1427541  439347531850  33795963988
# 31036    2.51427 7.84719   27319011  1241773  914553993050  41570636048
# 31037    3.01944 6.48131   53242389  2420109  123940698625   5633668119
# 31038    3.13701 6.08230  122995469  5590703  298029870405  13546812291
# 31039    3.87387 8.74860    4304227   614890   64649360220   9235622889
#
#        상장주식수대비월거래량합계_y  label
# 0              0.13720      1
# 1              0.95086      0
# 2              0.85987      1
# 3              1.01791      1
# 4              1.00858      1
# ...                ...    ...
# 31035         38.59300      0
# 31036         56.81219      0
# 31037         59.34477      0
# 31038        137.09261      0
# 31039        105.60136      0
#
# [31040 rows x 54 columns]

# %%
tkffuwnj1 = tkffuwnj.drop(['종목명', 'years', 'month','상장주식수대비월거래량합계_x', '거래대금_x','벤치마크지수','업종명', '업종월평균PBR','소외주','LOW P/B','거래소코드', '회계년도','EPS', 'PER', '총자본증가율(IFRS)', '자기자본증가율(IFRS)',
       '매출액증가율(IFRS)', '순이익증가율(IFRS)', '매출액순이익률(IFRS)', '총자본순이익률(IFRS)',
       '자기자본순이익률(IFRS)', '자본금순이익률(IFRS)', '유보율(IFRS)', '사내유보율(IFRS)',
       '자기자본배당률(IFRS)', '배당성향(IFRS)', '자기자본구성비율(IFRS)', '타인자본구성비율(IFRS)',
       '부채비율(IFRS)', '총자본회전률(IFRS)', '자기자본회전률(IFRS)', '자본금회전률(IFRS)',
       '타인자본회전률(IFRS)','PER(최저)(IFRS)', 'PBR(최저)(IFRS)',
       'PCR(최저)(IFRS)', 'PSR(최저)(IFRS)','상장시가총액', '거래량_합계','거래대금_합계','거래대금_y','시가총액'],axis=1)

# %%
tkffuwnj1.columns
# Out:
# Index(['BPS', 'PBR', '종가', '대비', '등락률', '거래량', '상장주식수대비거래량', '표준편차', '거래량_일평균',
#        '거래대금_일평균', '상장주식수대비월거래량합계_y', 'label'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rc('font', family='Malgun Gothic')

# %%
tkffuwnj1.corr()
plt.figure(figsize=(30,25))
sns.heatmap(tkffuwnj1.astype(float).corr(), linewidths = 0.1, vmax = 1.0,
           square = True, cmap = 'Blues', linecolor = "white", annot = True, annot_kws = {"size" :16})
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:>

# %%
tkffuwnj1 = tkffuwnj1.dropna(subset=['BPS'])

# %%
tkffuwnj1.isna().sum()
# Out:
# BPS                0
# PBR                0
# 종가                 0
# 대비                 0
# 등락률                0
# 거래량                0
# 상장주식수대비거래량         0
# 표준편차               0
# 거래량_일평균            0
# 거래대금_일평균           0
# 상장주식수대비월거래량합계_y    0
# label              0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X_train = tkffuwnj1[['BPS', 'PBR', '종가', '대비', '등락률', '거래량', '상장주식수대비거래량',
       '표준편차',  '거래량_일평균', '거래대금_일평균', '상장주식수대비월거래량합계_y',
       'label']]
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif['VIF_Factor'] = [variance_inflation_factor(X_train.values, i)
                         for i in range(X_train.shape[1])]
    vif['Feature'] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
#     VIF_Factor          Feature
# 0      2.37260              BPS
# 1      1.13397              PBR
# 2      2.47641               종가
# 3      1.14036               대비
# 4      1.24741              등락률
# 5      1.65175              거래량
# 6      1.81494       상장주식수대비거래량
# 7      1.15242             표준편차
# 8      1.70988          거래량_일평균
# 9      1.24296         거래대금_일평균
# 10     2.22984  상장주식수대비월거래량합계_y
# 11     1.97395            label

# %%
from scipy import stats
from scipy.stats import shapiro

# %%
tkffuwnj1.columns
# Out:
# Index(['BPS', 'PBR', '종가', '대비', '등락률', '거래량', '상장주식수대비거래량', '표준편차', '거래량_일평균',
#        '거래대금_일평균', '상장주식수대비월거래량합계_y', 'label'],
#       dtype='object')

# %%
from matplotlib.pyplot import imread
fig, axes = plt.subplots(3, 4)
fig.set_size_inches((20,20))

stats.probplot(tkffuwnj1["PBR"], dist=stats.norm, plot=axes[0,0])
axes[0,0].title.set_text("PBR")
stats.probplot(tkffuwnj1["종가"], dist=stats.norm, plot=axes[0,1])
axes[0,1].title.set_text("종가")
stats.probplot(tkffuwnj1["대비"], dist=stats.norm, plot=axes[0,2])
axes[0,2].title.set_text("대비")
stats.probplot(tkffuwnj1["BPS"], dist=stats.norm, plot=axes[0,3])
axes[0,3].title.set_text("BPS")
stats.probplot(tkffuwnj1["등락률"], dist=stats.norm, plot=axes[1,0])
axes[1,0].title.set_text("등락률")
stats.probplot(tkffuwnj1["거래량"], dist=stats.norm, plot=axes[1,1])
axes[1,1].title.set_text("거래량")
stats.probplot(tkffuwnj1["상장주식수대비거래량"], dist=stats.norm, plot=axes[1,2])
axes[1,2].title.set_text("상장주식수대비거래량")
stats.probplot(tkffuwnj1["표준편차"], dist=stats.norm, plot=axes[1,3])
axes[1,3].title.set_text("표준편차")
stats.probplot(tkffuwnj1["거래량_일평균"], dist=stats.norm, plot=axes[2,0])
axes[2,0].title.set_text("거래량_일평균")
stats.probplot(tkffuwnj1["거래대금_일평균"], dist=stats.norm, plot=axes[2,1])
axes[2,1].title.set_text("거래대금_일평균")
stats.probplot(tkffuwnj1["상장주식수대비월거래량합계_y"], dist=stats.norm, plot=axes[2,2])
axes[2,2].title.set_text("상장주식수대비월거래량합계_y")
stats.probplot(tkffuwnj1["label"], dist=stats.norm, plot=axes[2,3])
axes[2,3].title.set_text("label")
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df_data = up_tkffuwnj.drop(['label'],axis=1)
target = up_tkffuwnj['label']

# %%
from sklearn.preprocessing import StandardScaler
standardScaler = StandardScaler()
standardScaler.fit(df_data)
train_data_standardScaled = standardScaler.transform(df_data)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
standardScaler = StandardScaler()
standard_scaled = standardScaler.fit_transform(df_data)
standard_fit = pd.DataFrame(standard_scaled, columns=['BPS', 'PBR', '종가', '대비', '등락률', '거래량', '상장주식수대비거래량', '표준편차', '거래량_일평균','거래대금_일평균', '상장주식수대비월거래량합계_y'])
standard_fit
# Out:
#            BPS      PBR       종가       대비      등락률      거래량  상장주식수대비거래량  \
# 0     -0.21932 -0.26929 -0.28009  0.01395 -0.01267 -0.10436    -0.21739
# 1     -0.21932 -0.28677 -0.28505  0.01395 -0.01267 -0.10373    -0.21145
# 2     -0.21932 -0.28240 -0.28459  0.01395 -0.01267 -0.10434    -0.21721
# 3     -0.21932 -0.26056 -0.27874 -0.00457 -0.14094 -0.10443    -0.21810
# 4     -0.22019 -0.30862 -0.29225 -0.00457 -0.16018 -0.10198    -0.19488
# ...        ...      ...      ...      ...      ...      ...         ...
# 30822 -0.27674  1.84097 -0.16928 -0.18985 -0.71815 -0.08546    -0.17458
# 30823 -0.27674  2.59245 -0.10306 -0.22690 -0.65402  0.04782     0.13338
# 30824 -0.29877  0.76617 -0.36685  0.02692  0.42987  0.23675     0.20407
# 30825 -0.29877  0.80550 -0.36622 -0.06942 -2.52998  0.25004     0.22053
# 30826 -0.27169  0.24626 -0.29450  0.16217  1.24439 -0.08458     0.32365
#
#           표준편차  거래량_일평균  거래대금_일평균  상장주식수대비월거래량합계_y
# 0     -1.12373 -0.18202  -0.19211         -0.37904
# 1     -0.88206 -0.18110  -0.19123         -0.36920
# 2     -0.69822 -0.18111  -0.19126         -0.37030
# 3     -0.83322 -0.18078  -0.19088         -0.36838
# 4     -1.14367 -0.18063  -0.19090         -0.36850
# ...        ...      ...       ...              ...
# 30822  0.30754  0.14017   0.42979          0.08615
# 30823  3.16467  0.09822   0.57290          0.30654
# 30824  2.35583  0.36431  -0.08859          0.33717
# 30825  2.11954  1.08029   0.05707          1.27766
# 30826  3.69847 -0.04334  -0.02229          0.89672
#
# [30827 rows x 11 columns]

# %%
from matplotlib.pyplot import imread
fig, axes = plt.subplots(3, 4)
fig.set_size_inches((20,20))

stats.probplot(standard_fit["PBR"], dist=stats.norm, plot=axes[0,0])
axes[0,0].title.set_text("PBR")
stats.probplot(standard_fit["종가"], dist=stats.norm, plot=axes[0,1])
axes[0,1].title.set_text("종가")
stats.probplot(standard_fit["대비"], dist=stats.norm, plot=axes[0,2])
axes[0,2].title.set_text("대비")
stats.probplot(standard_fit["BPS"], dist=stats.norm, plot=axes[0,3])
axes[0,3].title.set_text("BPS")
stats.probplot(standard_fit["등락률"], dist=stats.norm, plot=axes[1,0])
axes[1,0].title.set_text("등락률")
stats.probplot(standard_fit["거래량"], dist=stats.norm, plot=axes[1,1])
axes[1,1].title.set_text("거래량")
stats.probplot(standard_fit["상장주식수대비거래량"], dist=stats.norm, plot=axes[1,2])
axes[1,2].title.set_text("상장주식수대비거래량")
stats.probplot(standard_fit["표준편차"], dist=stats.norm, plot=axes[1,3])
axes[1,3].title.set_text("표준편차")
stats.probplot(standard_fit["거래량_일평균"], dist=stats.norm, plot=axes[2,0])
axes[2,0].title.set_text("거래량_일평균")
stats.probplot(standard_fit["거래대금_일평균"], dist=stats.norm, plot=axes[2,1])
axes[2,1].title.set_text("거래대금_일평균")
stats.probplot(standard_fit["상장주식수대비월거래량합계_y"], dist=stats.norm, plot=axes[2,2])
axes[2,2].title.set_text("상장주식수대비월거래량합계_y")
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from matplotlib.pyplot import imread

fig, axes = plt.subplots(3, 5)
fig.set_size_inches((20,15))


tkffuwnj1.boxplot(column="PBR", ax=axes[0,0])
tkffuwnj1.boxplot(column="종가", ax=axes[0,1])
tkffuwnj1.boxplot(column="대비", ax=axes[0,2])
tkffuwnj1.boxplot(column="BPS", ax=axes[0,3])
tkffuwnj1.boxplot(column="등락률", ax=axes[0,4])
tkffuwnj1.boxplot(column="거래량", ax=axes[1,0])
tkffuwnj1.boxplot(column="상장주식수대비거래량", ax=axes[1,1])
tkffuwnj1.boxplot(column="표준편차", ax=axes[1,2])
tkffuwnj1.boxplot(column="거래량_일평균", ax=axes[1,3])
tkffuwnj1.boxplot(column="거래대금_일평균", ax=axes[1,4])
tkffuwnj1.boxplot(column="상장주식수대비월거래량합계_y", ax=axes[2,0])
# Out:
# <AxesSubplot:>
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
train_data_standardScaled
# Out:
# array([[-0.21931553, -0.26929488, -0.28009037, ..., -0.18202024,
#         -0.19211487, -0.37903815],
#        [-0.21931553, -0.28677116, -0.28504539, ..., -0.18110048,
#         -0.19123264, -0.36919554],
#        [-0.21931553, -0.28240209, -0.28459493, ..., -0.18111087,
#         -0.19126397, -0.37029623],
#        ...,
#        [-0.29877309,  0.76617487, -0.36684823, ...,  0.36431404,
#         -0.08858926,  0.33717307],
#        [-0.29877309,  0.80549651, -0.36621759, ...,  1.08029469,
#          0.05706669,  1.2776587 ],
#        [-0.27169075,  0.24625546, -0.29450497, ..., -0.04333887,
#         -0.02228867,  0.89672118]])

# %%
import numpy as np

# %%
tkffuwnj1.isna().sum()
# Out:
# BPS                0
# PBR                0
# 종가                 0
# 대비                 0
# 등락률                0
# 거래량                0
# 상장주식수대비거래량         0
# 표준편차               0
# 거래량_일평균            0
# 거래대금_일평균           0
# 상장주식수대비월거래량합계_y    0
# label              0
# dtype: int64

# %%
up_tkffuwnj = pd.pivot_table(tkffuwnj, index=['업종명','종목명','years','month'])

# %%
up_tkffuwnj
# Out:
#                              BPS        EPS     PBR  PBR(최저)(IFRS)  \
# 업종명 종목명  years month
# 건설업 금호건설 2021  4     10364.00000  332.00000 0.97000        0.48000
#                5     10569.00000  741.00000 1.11000        0.48000
#                6     10569.00000  741.00000 1.20000        0.48000
#                7     10569.00000  741.00000 1.18000        0.48000
#                8     10569.00000  741.00000 1.24000        0.48000
# ...                          ...        ...     ...            ...
# 화학  휴비스  2021  8     13659.00000 2497.00000 0.76000        0.65000
#                9     13659.00000 2497.00000 0.74000        0.65000
#                10    13659.00000 2497.00000 0.71000        0.65000
#                11    13659.00000 2497.00000 0.56000        0.65000
#                12    13659.00000 2497.00000 0.63000        0.65000
#
#                       PCR(최저)(IFRS)      PER  PER(최저)(IFRS)  PSR(최저)(IFRS)  \
# 업종명 종목명  years month
# 건설업 금호건설 2021  4            1.66000 30.27000        1.99000        0.14000
#                5            1.66000 15.79000        1.99000        0.14000
#                6            1.66000 17.14000        1.99000        0.14000
#                7            1.66000 16.87000        1.99000        0.14000
#                8            1.66000 17.68000        1.99000        0.14000
# ...                             ...      ...            ...            ...
# 화학  휴비스  2021  8            0.00000  4.16000       80.16000        0.29000
#                9            0.00000  4.02000       80.16000        0.29000
#                10           0.00000  3.91000       80.16000        0.29000
#                11           0.00000  3.08000       80.16000        0.29000
#                12           0.00000  3.44000       80.16000        0.29000
#
#                       label         거래대금_x  ...  자기자본회전률(IFRS)  자본금순이익률(IFRS)  \
# 업종명 종목명  years month                        ...
# 건설업 금호건설 2021  4          1 15736822.45455  ...        3.88000       80.96000
#                5          1 15976395.78947  ...        3.88000       80.96000
#                6          1 16947706.77273  ...        3.88000       80.96000
#                7          1 13814302.18182  ...        3.88000       80.96000
#                8          1 15521821.09524  ...        3.88000       80.96000
# ...                     ...            ...  ...            ...            ...
# 화학  휴비스  2021  8          1 15521821.09524  ...        2.10000        1.87000
#                9          1 14061364.42105  ...        2.10000        1.87000
#                10         1 11753813.78947  ...        2.10000        1.87000
#                11         1 11717785.81818  ...        2.10000        1.87000
#                12         1  9919548.95455  ...        2.10000        1.87000
#
#                       자본금회전률(IFRS)     종가  총자본순이익률(IFRS)  총자본증가율(IFRS)  \
# 업종명 종목명  years month
# 건설업 금호건설 2021  4          11.18000  10050        9.58000      26.12000
#                5          11.18000  11700        9.58000      26.12000
#                6          11.18000  12700        9.58000      26.12000
#                7          11.18000  12500        9.58000      26.12000
#                8          11.18000  13100        9.58000      26.12000
# ...                            ...    ...            ...           ...
# 화학  휴비스  2021  8           5.13000  10400        0.42000      -6.51000
#                9           5.13000  10050        0.42000      -6.51000
#                10          5.13000   9760        0.42000      -6.51000
#                11          5.13000   7690        0.42000      -6.51000
#                12          5.13000   8590        0.42000      -6.51000
#
#                       총자본회전률(IFRS)  타인자본구성비율(IFRS)  타인자본회전률(IFRS)    표준편차
# 업종명 종목명  years month
# 건설업 금호건설 2021  4           1.32000        61.85000        2.01000 1.47468
#                5           1.32000        61.85000        2.01000 2.62146
#                6           1.32000        61.85000        2.01000 3.37398
#                7           1.32000        61.85000        2.01000 1.58975
#                8           1.32000        61.85000        2.01000 2.70536
# ...                            ...             ...            ...     ...
# 화학  휴비스  2021  8           1.15000        43.82000        2.56000 2.40395
#                9           1.15000        43.82000        2.56000 1.70225
#                10          1.15000        43.82000        2.56000 1.66339
#                11          1.15000        43.82000        2.56000 1.96738
#                12          1.15000        43.82000        2.56000 1.42215
#
# [31040 rows x 47 columns]

# %%
up_tkffuwnj1 = up_tkffuwnj.loc['건설업']

# %%
up_tkffuwnj1
# Out:
#                          BPS        EPS     PBR  PBR(최저)(IFRS)  PCR(최저)(IFRS)  \
# 종목명  years month
# 금호건설 2021  4     10364.00000  332.00000 0.97000        0.48000        1.66000
#            5     10569.00000  741.00000 1.11000        0.48000        1.66000
#            6     10569.00000  741.00000 1.20000        0.48000        1.66000
#            7     10569.00000  741.00000 1.18000        0.48000        1.66000
#            8     10569.00000  741.00000 1.24000        0.48000        1.66000
# ...                      ...        ...     ...            ...            ...
# 화성산업 2021  8     31644.00000 2742.00000 0.41000        0.34000        1.05000
#            9     31644.00000 2742.00000 0.45000        0.34000        1.05000
#            10    31644.00000 2742.00000 0.42000        0.34000        1.05000
#            11    31644.00000 2742.00000 0.35000        0.34000        1.05000
#            12    31644.00000 2742.00000 0.40000        0.34000        1.05000
#
#                       PER  PER(최저)(IFRS)  PSR(최저)(IFRS)  label         거래대금_x  \
# 종목명  years month
# 금호건설 2021  4     30.27000        1.99000        0.14000      1 15736822.45455
#            5     15.79000        1.99000        0.14000      1 15976395.78947
#            6     17.14000        1.99000        0.14000      1 16947706.77273
#            7     16.87000        1.99000        0.14000      1 13814302.18182
#            8     17.68000        1.99000        0.14000      1 15521821.09524
# ...                   ...            ...            ...    ...            ...
# 화성산업 2021  8      4.69000        4.54000        0.32000      1 15521821.09524
#            9      5.22000        4.54000        0.32000      1 14061364.42105
#            10     4.89000        4.54000        0.32000      1 11753813.78947
#            11     4.07000        4.54000        0.32000      1 11717785.81818
#            12     4.60000        4.54000        0.32000      1  9919548.95455
#
#                   ...  자기자본회전률(IFRS)  자본금순이익률(IFRS)  자본금회전률(IFRS)     종가  \
# 종목명  years month  ...
# 금호건설 2021  4      ...        3.88000       80.96000      11.18000  10050
#            5      ...        3.88000       80.96000      11.18000  11700
#            6      ...        3.88000       80.96000      11.18000  12700
#            7      ...        3.88000       80.96000      11.18000  12500
#            8      ...        3.88000       80.96000      11.18000  13100
# ...               ...            ...            ...           ...    ...
# 화성산업 2021  8      ...        1.04000       47.99000       6.78000  12850
#            9      ...        1.04000       47.99000       6.78000  14300
#            10     ...        1.04000       47.99000       6.78000  13400
#            11     ...        1.04000       47.99000       6.78000  11150
#            12     ...        1.04000       47.99000       6.78000  12600
#
#                   총자본순이익률(IFRS)  총자본증가율(IFRS)  총자본회전률(IFRS)  타인자본구성비율(IFRS)  \
# 종목명  years month
# 금호건설 2021  4            9.58000      26.12000       1.32000        61.85000
#            5            9.58000      26.12000       1.32000        61.85000
#            6            9.58000      26.12000       1.32000        61.85000
#            7            9.58000      26.12000       1.32000        61.85000
#            8            9.58000      26.12000       1.32000        61.85000
# ...                         ...           ...           ...             ...
# 화성산업 2021  8            5.05000      24.39000       0.71000        36.50000
#            9            5.05000      24.39000       0.71000        36.50000
#            10           5.05000      24.39000       0.71000        36.50000
#            11           5.05000      24.39000       0.71000        36.50000
#            12           5.05000      24.39000       0.71000        36.50000
#
#                   타인자본회전률(IFRS)    표준편차
# 종목명  years month
# 금호건설 2021  4            2.01000 1.47468
#            5            2.01000 2.62146
#            6            2.01000 3.37398
#            7            2.01000 1.58975
#            8            2.01000 2.70536
# ...                         ...     ...
# 화성산업 2021  8            2.26000 1.67968
#            9            2.26000 3.47012
#            10           2.26000 2.25499
#            11           2.26000 1.33480
#            12           2.26000 1.75709
#
# [1122 rows x 47 columns]

# %%
up_tkffuwnj1 = up_tkffuwnj1.drop(['상장주식수대비월거래량합계_x', '거래대금_x','벤치마크지수', '업종월평균PBR','거래소코드','EPS', 'PER', '총자본증가율(IFRS)', '자기자본증가율(IFRS)',
       '매출액증가율(IFRS)', '순이익증가율(IFRS)', '매출액순이익률(IFRS)', '총자본순이익률(IFRS)',
       '자기자본순이익률(IFRS)', '자본금순이익률(IFRS)', '유보율(IFRS)', '사내유보율(IFRS)',
       '자기자본배당률(IFRS)', '배당성향(IFRS)', '자기자본구성비율(IFRS)', '타인자본구성비율(IFRS)',
       '부채비율(IFRS)', '총자본회전률(IFRS)', '자기자본회전률(IFRS)', '자본금회전률(IFRS)',
       '타인자본회전률(IFRS)','PER(최저)(IFRS)', 'PBR(최저)(IFRS)',
       'PCR(최저)(IFRS)', 'PSR(최저)(IFRS)','시가총액'], axis=1)

# %%
up_tkffuwnj1.columns
# Out:
# Index(['BPS', 'PBR', 'label', '거래대금_y', '거래대금_일평균', '거래대금_합계', '거래량',
#        '거래량_일평균', '거래량_합계', '대비', '등락률', '상장시가총액', '상장주식수대비거래량',
#        '상장주식수대비월거래량합계_y', '종가', '표준편차'],
#       dtype='object')

# %%
from matplotlib.pyplot import imread
fig, axes = plt.subplots(3, 4)
fig.set_size_inches((20,20))

stats.probplot(up_tkffuwnj1["PBR"], dist=stats.norm, plot=axes[0,0])
axes[0,0].title.set_text("PBR")
stats.probplot(up_tkffuwnj1["종가"], dist=stats.norm, plot=axes[0,1])
axes[0,1].title.set_text("종가")
stats.probplot(up_tkffuwnj1["거래대금_y"], dist=stats.norm, plot=axes[0,2])
axes[0,2].title.set_text("대비")
stats.probplot(up_tkffuwnj1["BPS"], dist=stats.norm, plot=axes[0,3])
axes[0,3].title.set_text("BPS")
stats.probplot(up_tkffuwnj1["등락률"], dist=stats.norm, plot=axes[1,0])
axes[1,0].title.set_text("등락률")
stats.probplot(up_tkffuwnj1["거래량"], dist=stats.norm, plot=axes[1,1])
axes[1,1].title.set_text("거래량")
stats.probplot(up_tkffuwnj1["상장주식수대비거래량"], dist=stats.norm, plot=axes[1,2])
axes[1,2].title.set_text("상장주식수대비거래량")
stats.probplot(up_tkffuwnj1["표준편차"], dist=stats.norm, plot=axes[1,3])
axes[1,3].title.set_text("표준편차")
stats.probplot(up_tkffuwnj1["거래량_일평균"], dist=stats.norm, plot=axes[2,0])
axes[2,0].title.set_text("거래량_일평균")
stats.probplot(up_tkffuwnj1["거래대금_일평균"], dist=stats.norm, plot=axes[2,1])
axes[2,1].title.set_text("거래대금_일평균")
stats.probplot(up_tkffuwnj1["상장주식수대비월거래량합계_y"], dist=stats.norm, plot=axes[2,2])
axes[2,2].title.set_text("상장주식수대비월거래량합계_y")
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
up_tkffuwnj1.columns
# Out:
# Index(['BPS', 'PBR', 'label', '거래대금_y', '거래대금_일평균', '거래대금_합계', '거래량',
#        '거래량_일평균', '거래량_합계', '대비', '등락률', '상장시가총액', '상장주식수대비거래량',
#        '상장주식수대비월거래량합계_y', '종가', '표준편차'],
#       dtype='object')

# %%
df_data = up_tkffuwnj1.drop(['label','종목명','years','month','업종명'],axis=1)
target = up_tkffuwnj1['label']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-155-6afa778afd9e> in <module>
# ----> 1 df_data = up_tkffuwnj1.drop(['label','종목명','years','month','업종명'],axis=1)
#       2 target = up_tkffuwnj1['label']
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['종목명' 'years' 'month' '업종명'] not found in axis"

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
standardScaler = RobustScaler()
standard_scaled = standardScaler.fit_transform(up_tkffuwnj1)
standard_fit = pd.DataFrame(standard_scaled, columns=['BPS', 'PBR', 'label', '거래대금_y', '거래대금_일평균', '거래대금_합계', '거래량',
       '거래량_일평균', '거래량_합계', '대비', '등락률', '상장시가총액', '상장주식수대비거래량',
       '상장주식수대비월거래량합계_y', '종가', '표준편차'])
standard_fit
# Out:
#           BPS      PBR   label   거래대금_y  거래대금_일평균  거래대금_합계      거래량  거래량_일평균  \
# 0    -0.00696  0.20000 0.00000  0.69496   0.55325  0.62875  0.35430  0.31588
# 1     0.00567  0.41538 0.00000  4.02343   1.35326  1.25094  1.97562  0.78123
# 2     0.00567  0.55385 0.00000  1.03323   1.97644  2.16872  0.39114  0.94926
# 3     0.00567  0.52308 0.00000  1.54458   0.89266  0.99600  0.65048  0.34990
# 4     0.00567  0.61538 0.00000  1.39041   0.39404  0.42250  0.54136  0.11404
# ...       ...      ...     ...      ...       ...      ...      ...      ...
# 1117  1.30339 -0.66154 0.00000 -0.22722  -0.14065 -0.12976 -0.20931 -0.19245
# 1118  1.30339 -0.60000 0.00000  0.28670   1.95921  1.81720  0.00135  0.73475
# 1119  1.30339 -0.64615 0.00000  0.04511   0.05454  0.03729 -0.08820 -0.09718
# 1120  1.30339 -0.75385 0.00000  0.09438  -0.07256 -0.04841 -0.03383 -0.15333
# 1121  1.30339 -0.67692 0.00000 -0.16646  -0.07714 -0.05336 -0.17952 -0.15834
#
#        거래량_합계       대비      등락률  상장시가총액  상장주식수대비거래량  상장주식수대비월거래량합계_y      종가  \
# 0     0.34974 -1.05263 -0.73934 2.73734     0.41038          0.41209 0.15594
# 1     0.69000  1.31579  0.82654 2.78005     2.88548          0.93453 0.31047
# 2     1.02175  1.57895  0.91754 3.03477     0.46661          1.44389 0.40412
# 3     0.38583 -2.10526 -1.17536 3.05109     0.86253          0.46751 0.38539
# 4     0.11661  0.52632  0.29194 3.04667     0.69594          0.05414 0.44158
# ...       ...      ...      ...     ...         ...              ...     ...
# 1117 -0.19378  0.00000  0.00000 3.04667    -0.34974         -0.15951 0.41817
# 1118  0.64741 -1.31579 -0.65213 3.02767     0.59649          3.64069 0.55397
# 1119 -0.11489 -1.57895 -0.83033 2.59850     0.19424          0.19690 0.46968
# 1120 -0.14808 -1.84211 -1.15261 2.63390     0.43845          0.04695 0.25896
# 1121 -0.15340 -0.52632 -0.29953 2.74887    -0.21593          0.02293 0.39476
#
#          표준편차
# 0    -0.51245
# 1     0.18862
# 2     0.64867
# 3    -0.44211
# 4     0.23991
# ...       ...
# 1117 -0.38713
# 1118  0.70744
# 1119 -0.03542
# 1120 -0.59796
# 1121 -0.33980
#
# [1122 rows x 16 columns]

# %%
standard_fit.drop(['label','years','month','종목명','업종명'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-163-ed363e176915> in <module>
# ----> 1 standard_fit.drop(['label','years','month','종목명','업종명'],axis=1,inplace=True)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['years' 'month' '종목명' '업종명'] not found in axis"

# %%
from matplotlib.pyplot import imread
fig, axes = plt.subplots(3, 4)
fig.set_size_inches((20,20))

stats.probplot(standard_fit["PBR"], dist=stats.norm, plot=axes[0,0])
axes[0,0].title.set_text("PBR")
stats.probplot(standard_fit["종가"], dist=stats.norm, plot=axes[0,1])
axes[0,1].title.set_text("종가")
stats.probplot(standard_fit["대비"], dist=stats.norm, plot=axes[0,2])
axes[0,2].title.set_text("대비")
stats.probplot(standard_fit["BPS"], dist=stats.norm, plot=axes[0,3])
axes[0,3].title.set_text("BPS")
stats.probplot(standard_fit["등락률"], dist=stats.norm, plot=axes[1,0])
axes[1,0].title.set_text("등락률")
stats.probplot(standard_fit["거래량"], dist=stats.norm, plot=axes[1,1])
axes[1,1].title.set_text("거래량")
stats.probplot(standard_fit["상장주식수대비거래량"], dist=stats.norm, plot=axes[1,2])
axes[1,2].title.set_text("상장주식수대비거래량")
stats.probplot(standard_fit["표준편차"], dist=stats.norm, plot=axes[1,3])
axes[1,3].title.set_text("표준편차")
stats.probplot(standard_fit["거래량_일평균"], dist=stats.norm, plot=axes[2,0])
axes[2,0].title.set_text("거래량_일평균")
stats.probplot(standard_fit["거래대금_일평균"], dist=stats.norm, plot=axes[2,1])
axes[2,1].title.set_text("거래대금_일평균")
stats.probplot(standard_fit["상장주식수대비월거래량합계_y"], dist=stats.norm, plot=axes[2,2])
axes[2,2].title.set_text("상장주식수대비월거래량합계_y")
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
