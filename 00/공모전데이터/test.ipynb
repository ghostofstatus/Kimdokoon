# %%
import krx
import imp
imp.reload(krx)
# Out:
# <module 'krx' from 'c:\\Users\\김성휘\\Desktop\\공모전데이터\\krx.py'>

# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import FinanceDataReader as fdr
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from pykrx import stock

# %%
df = krx.pykrx('종목별공매도현황','거래량','008770','20210709','20220709')

# %%
df_1 = krx.pykrx('종목별공매도거래정보','공매도','','20220711','')

# %%
df = krx.rank1('공매도비중','20220713')
# Out:
# c:\Users\김성휘\Desktop\공모전데이터\krx.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위험도'][i] += 1
# c:\Users\김성휘\Desktop\공모전데이터\krx.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위험도'][i] += 2
# c:\Users\김성휘\Desktop\공모전데이터\krx.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위험도'][i] += 1
# c:\Users\김성휘\Desktop\공모전데이터\krx.py:60: SettingWithCopyWarning:
# ...

# %%
krx.rank('공매도비중','20220713')
# Out:
#         순위      공매도거래대금        총거래대금  공매도비중  직전40일거래대금평균  공매도거래대금증가율  \
# 티커
# 000210   1   1587919300   4201766900  37.79    857058385        1.85
# 112610   2   3788814000  10949242600  34.60   1929450130        1.96
# 042670   3   1806986340   5961563690  30.31   1039923528        1.74
# 001450   4   2658845100  10730529350  24.78   1386606825        1.92
# 001230   5   1104748600   4496048800  24.57    367231460        3.01
# 034220   6   4845456300  19749346500  24.54   5139493969        0.94
# 271940   7    491994600   2109295150  23.32    558537056        0.88
# 373220   8  20621848500  89361995000  23.08  25712447038        0.80
# 326030   9   1287620800   5643528900  22.82   1877560155        0.69
# 012450  10   4102655050  18033075150  22.75   1232580973        3.33
# 014820  11    109095500    492067800  22.17     95799594        1.14
# 030200  12   5347910950  25377024400  21.07   2355718291        2.27
# ...

# %%
df_2 = krx.rank1('공매도위험도')
df_2
# Out:
# c:\Users\김성휘\Desktop\공모전데이터\krx.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위험도'][i] += 1
# c:\Users\김성휘\Desktop\공모전데이터\krx.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위험도'][i] += 3
# c:\Users\김성휘\Desktop\공모전데이터\krx.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위험도'][i] += 2
# c:\Users\김성휘\Desktop\공모전데이터\krx.py:59: SettingWithCopyWarning:
# ...

# %%
df = stock.get_shorting_status_by_date("20181210", "20181212", "005930")
df.columns
# Out:
# Index(['거래량', '잔고수량', '거래대금', '잔고금액'], dtype='object')

# %%
df = stock.get_shorting_status_by_date("20181210", "20181212", "005930")
print(df)
# Out:
#                 거래량     잔고수량         거래대금          잔고금액
# 날짜
# 2018-12-10  2180611  4728327  87700923850  190078745400
# 2018-12-11   701924  4249549  28291624600  171044347250
# 2018-12-12    40002  4236519   1618884450  171367193550

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
date = widgets.DatePicker(description='')

# %%
label_headline = widgets.Label(
                    value='Photo by CDC on Unsplash',
                )

vbox_headline = widgets.VBox([label_headline])

# %%
text_1 = widgets.HTML(value="<h2>날짜 선택</h2>")
text_2 = widgets.HTML(value="<h2>패턴 예측</h2>")


vbox_1 = widgets.VBox([text_1, date])
vbox_2 = widgets.VBox([text_2, vbox_result])

# %%
page = widgets.VBox([ vbox_1 , vbox_2])
display(page)
