# %%
import func as fun
import imp
imp.reload(fun)
# Out:
# <module 'func' from 'c:\\Users\\김성휘\\Desktop\\공모전데이터\\func.py'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df2 = pd.read_csv("./csv/공매도잔량.csv", encoding='CP949')

# %%
df1 = fun.gongmae(df2)
## 코스피 200 공매도잔고수량

# %%
df3 = pd.read_csv("./csv/코스피200종가.csv", encoding='CP949')

# %%
df4 = fun.jongga(df3)
## 코스피 200 종가

# %%
hosin_gong = pd.read_csv("./csv/호텔신라공매도잔고.csv", encoding='CP949')
hosin_gong
# Out:
#              일자  수량_공매도잔고수량  수량_상장주식수    금액_공매도잔고금액        금액_시가총액    비중
# 0    2022/07/07     2852905  39248121  197421026000  2715969973200  7.27
# 1    2022/07/06     2851481  39248121  194471004200  2676721852200  7.27
# 2    2022/07/05     2859280  39248121  197290320000  2708120349000  7.29
# 3    2022/07/04     2896948  39248121  196413074400  2661022603800  7.38
# 4    2022/07/01     2885817  39248121  198832791300  2704195536900  7.35
# ..          ...         ...       ...           ...            ...   ...
# 240  2021/07/15     1115442  39248121  105297724800  3705022622400  2.84
# 241  2021/07/14     1139640  39248121  106670304000  3673624125600  2.90
# 242  2021/07/13     1135379  39248121  108201618700  3740345931300  2.89
# 243  2021/07/12     1132627  39248121  105674099100  3661849689300  2.89
# 244  2021/07/09     1133159  39248121  105043839300  3638300816700  2.89
#
# [245 rows x 6 columns]

# %%
hosin_jong = pd.read_csv("./csv/호텔신라종가.csv", encoding='CP949')

# %%
hosin_gong_1 = fun.gongmae2(hosin_gong)
hosin_jong2 = fun.jongga2(hosin_jong)

## 호텔신라 공매도잔고수량,종가

# %%
HMM_gong = pd.read_csv("./csv/HMM공매도잔고.csv", encoding='CP949')
HMM_jong = pd.read_csv("./csv/HMM종가.csv", encoding='CP949')
HMM_gong2 = fun.gongmae2(HMM_gong)
HMM_jong2 = fun.jongga2(HMM_jong)

## HMM 공매도잔고수량, 종가

# %%
Du_g=pd.read_csv("./csv/두산퓨얼셀공매도잔고.csv", encoding='CP949')
Du_j=pd.read_csv("./csv/두산퓨얼셀종가.csv", encoding='CP949')
Du_g2 = fun.gongmae2(Du_g)
Du_j2 = fun.jongga2(Du_j)

## 두산퓨얼셀 공매도잔고, 종가

# %%
hyo_g=pd.read_csv("./csv/효성첨단소재공매도잔고.csv", encoding='CP949')
hyo_j=pd.read_csv("./csv/효성첨단소재종가.csv", encoding='CP949')
hyo_g2 = fun.gongmae2(hyo_g)
hyo_j2 = fun.jongga2(hyo_j)

## 효성첨단소재 공매도잔고 , 종가

# %%
Amo_g = pd.read_csv("./csv/아모레공매도잔고.csv", encoding='CP949')
Amo_j = pd.read_csv("./csv/아모레종가.csv", encoding='CP949')
Amo_g2 = fun.gongmae2(Amo_g)
Amo_j2 = fun.jongga2(Amo_j)

## 아모레 공매도잔고, 종가

# %%
LGd_g=pd.read_csv("./csv/LG디스플레이공매도잔고.csv", encoding='CP949')
LGd_j=pd.read_csv("./csv/LG종가.csv", encoding='CP949')
LGd_g2 = fun.gongmae2(LGd_g)
LGd_j2 = fun.jongga2(LGd_j)

## LG디스플레이 공매도 잔고 , 종가

# %%
hyn_g = pd.read_csv("./csv/현대로템공매도잔고.csv", encoding='CP949')
hyn_j = pd.read_csv("./csv/현대로템종가.csv",encoding='CP949')
hyn_g2 = fun.gongmae2(hyn_g)
hyn_j2 = fun.jongga2(hyn_j)

## 현대로템 공매도잔고, 종가

# %%
pos_g = pd.read_csv("./csv/포스코케미컬공매도잔고.csv", encoding='CP949')
pos_j = pd.read_csv("./csv/포스코케미컬종가.csv",encoding='CP949')
pos_g2 = fun.gongmae2(pos_g)
pos_j2 = fun.jongga2(pos_j)

## 포스코케미컬 공매도잔고,종가

# %%
SK_g = pd.read_csv("./csv/SK바이오사이언스공매도잔고.csv",encoding='CP949')
SK_j = pd.read_csv("./csv/SK바이오사이언스종가.csv",encoding='CP949')
SK_g2 = fun.gongmae2(SK_g)
SK_j2 = fun.jongga2(SK_j)

## SK바이오사이언스 공매도잔고, 종가

# %%
Kakao_g = pd.read_csv("./csv/카카오뱅크공매도잔고.csv",encoding='CP949')
Kakao_j = pd.read_csv("./csv/카카오뱅크종가.csv",encoding='CP949')
Kakao_g2 = fun.gongmae2(Kakao_g)
Kakao_j2 = fun.jongga2(Kakao_j)

## 카카오뱅크 공매도잔고, 종가
