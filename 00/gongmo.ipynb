# %%
import gongmo
import imp
imp.reload(gongmo)
# Out:
# <module 'gongmo' from 'c:\\Users\\LG\\OneDrive\\바탕 화면\\새 폴더\\gongmo.py'>

# %%
df8 = gongmo.dan('178920','20220125','20220124')
# Out:
# c:\Users\LG\OneDrive\바탕 화면\새 폴더\gongmo.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rank_name_many['위험도수치'][i] += 5
# c:\Users\LG\OneDrive\바탕 화면\새 폴더\gongmo.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rank_name_many['위험도수치'][i] += 3
# c:\Users\LG\OneDrive\바탕 화면\새 폴더\gongmo.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rank_name_many['위험도수치'][i] += 5
# ...

# %%
df
# Out:
#          시가     종가    등락률     공매도거래대금  직전40일거래대금평균  공매도거래대금증가율  공매도비중  \
# 종목명
# 코스맥스  70100  63600 -12.28  8988470700   1188016533        7.57  21.66
#
#       직전40일공매도평균비중  공매도비중증가율    잔고수량   잔고수량증가율  순위  과열횟수  위험도수치     위험도
# 종목명
# 코스맥스         12.45      1.74  229563 -8.498756  28   3.0     15  Level4

# %%
df1
# Out:
#          시가     종가   등락률     공매도거래대금  직전40일거래대금평균  공매도거래대금증가율  공매도비중  \
# 종목명
# 한국콜마  41700  39650 -6.04  8937428400   1042457615        8.57  39.46
#
#       직전40일공매도평균비중  공매도비중증가율    잔고수량    잔고수량증가율  순위  과열횟수  위험도수치     위험도
# 종목명
# 한국콜마         14.97      2.64  895706 -21.724093   2   3.0     15  Level4

# %%
df2
# Out:
#            시가     종가   등락률     공매도거래대금  직전40일거래대금평균  공매도거래대금증가율  공매도비중  \
# 종목명
# 대우조선해양  23300  21450 -9.49  8489936750    918371098        9.24  23.26
#
#         직전40일공매도평균비중  공매도비중증가율     잔고수량    잔고수량증가율  순위  과열횟수  위험도수치     위험도
# 종목명
# 대우조선해양          8.97      2.59  2154115 -20.249244  16   1.0     14  Level3

# %%
df3
# Out:
#         시가     종가    등락률      공매도거래대금  직전40일거래대금평균  공매도거래대금증가율  공매도비중  \
# 종목명
# 넷마블  79000  72300 -13.83  27042880700   3370442295        8.02   30.2
#
#      직전40일공매도평균비중  공매도비중증가율     잔고수량    잔고수량증가율  순위  과열횟수  위험도수치     위험도
# 종목명
# 넷마블         21.71      1.39  1081319 -19.024913  10   4.0     15  Level4

# %%
df4
# Out:
#           시가     종가    등락률      공매도거래대금  직전40일거래대금평균  공매도거래대금증가율  공매도비중  \
# 종목명
# GS리테일  28000  26400 -10.05  15017522200    528221106       28.43  32.46
#
#        직전40일공매도평균비중  공매도비중증가율    잔고수량    잔고수량증가율  순위  과열횟수  위험도수치     위험도
# 종목명
# GS리테일           8.8      3.69  660175 -60.334457   2   2.0     17  Level4

# %%
df5
# Out:
#           시가      종가   등락률      공매도거래대금  직전40일거래대금평균  공매도거래대금증가율  공매도비중  \
# 종목명
# 삼성전기  161500  156500 -5.44  48543488500   6593706213        7.36  24.66
#
#       직전40일공매도평균비중  공매도비중증가율    잔고수량    잔고수량증가율  순위  과열횟수  위험도수치     위험도
# 종목명
# 삼성전기          6.48      3.81  935199 -24.897054  11   2.0     14  Level3

# %%
df6
# Out:
#         시가    종가  등락률      공매도거래대금  직전40일거래대금평균  공매도거래대금증가율  공매도비중  \
# 종목명
# 대한전선  1570  1460 -7.3  14196875190    681269871       20.84  35.58
#
#       직전40일공매도평균비중  공매도비중증가율      잔고수량   잔고수량증가율  순위  과열횟수  위험도수치     위험도
# 종목명
# 대한전선          5.43      6.55  19282024 -52.48324   1   4.0     17  Level4

# %%
df7
# Out:
#           시가      종가  등락률      공매도거래대금  직전40일거래대금평균  공매도거래대금증가율  공매도비중  \
# 종목명
# 삼성화재  207000  197500 -6.4  17515157500   2573776263         6.8  22.36
#
#       직전40일공매도평균비중  공매도비중증가율    잔고수량    잔고수량증가율  순위  과열횟수  위험도수치     위험도
# 종목명
# 삼성화재         12.87      1.74  181116 -21.269794   4   2.0     12  Level3

# %%
df8
# Out:
#            시가     종가   등락률     공매도거래대금  직전40일거래대금평균  공매도거래대금증가율  공매도비중  \
# 종목명
# PI첨단소재  48300  42900 -13.6  5858228800    609509321        9.61  12.93
#
#         직전40일공매도평균비중  공매도비중증가율    잔고수량    잔고수량증가율  순위  과열횟수  위험도수치     위험도
# 종목명
# PI첨단소재          5.96      2.17  385827 -25.007063  36   1.0     14  Level3
